# %%
import pandas as pd 
import numpy as np
import os
import time
from datetime import datetime
from pandas.compat import StringIO
import re

# %%
fileLocation = 'C:\\Yuva\\ITU\\3rd Sem\\Research Topics\\Movies & Gender\\Website - IMDB\\name\\data.tsv'
saveFileToPath = "C:\\Yuva\\ITU\\3rd Sem\\Research Topics\\Movies & Gender\\Website - IMDB\\name"

# %%
# Import as Dataframe
df = pd.read_csv(fileLocation, sep='\t')

# %%
df.head(10)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0072308,tt0053137,tt0050419,tt0043044
# 1              actress,soundtrack  tt0071877,tt0117057,tt0038355,tt0037382
# 2     actress,soundtrack,producer  tt0049189,tt0057345,tt0054452,tt0059956
# 3         actor,writer,soundtrack  tt0072562,tt0077975,tt0080455,tt0078723
# ...

# %%
explodeFileLocation = 'C:\\Yuva\\ITU\\3rd Sem\\Research Topics\\Movies & Gender\\Data\\IMDb\\1stNov2019_explode.csv'
saveMergeFilePath = 'C:\\Yuva\\ITU\\3rd Sem\\Research Topics\\Movies & Gender\\Data\\IMDb'
explodedDF = pd.read_csv(explodeFileLocation,encoding="utf8")

# %%
explodedDF.rename(columns={'director_ids':'nconst'}, inplace=True)

# %%
explodedAndMergedDF = explodedDF.merge(df, on='nconst')
explodedAndMergedDF.head()
# Out:
#       nconst   movie_id                                        title  \
# 0  nm0005690  tt0000001      Carmencita - spanyol tánc (1894) - IMDb
# 1  nm0005690  tt0000005                A patkolókovács (1893) - IMDb
# 2  nm0005690  tt0000006             Kínai ópiumbarlang (1894) - IMDb
# 3  nm0005690  tt0000007  A Corbett-Courtney bokszmeccs (1894) - IMDb
# 4  nm0005690  tt0000008   Edison asszisztense tüsszent (1894) - IMDb
#
#   review_count_user review_count_critic metascore rating_value rating_count  \
# 0                12                   2      None          5.8         1255
# 1                18                   3      None          6.2         1499
# 2              None                None      None          5.7           70
# 3                 5                   2      None          5.5          499
# 4                19                   4      None          5.6         1341
#
#   date_published           primaryName birthYear deathYear  \
# ...

# %%
explodedAndMergedDF = explodedAndMergedDF.sort_values(by ='movie_id')
explodedAndMergedDF.head()
# Out:
#        nconst   movie_id                                    title  \
# 0   nm0005690  tt0000001  Carmencita - spanyol tánc (1894) - IMDb
# 72  nm0721526  tt0000002          A bohóc és kutyái (1892) - IMDb
# 73  nm0721526  tt0000003            Szegény Pierrot (1892) - IMDb
# 74  nm0721526  tt0000004           Egy jó pohár sör (1892) - IMDb
# 1   nm0005690  tt0000005            A patkolókovács (1893) - IMDb
#
#    review_count_user review_count_critic metascore rating_value rating_count  \
# 0                 12                   2      None          5.8         1255
# 72                 0                None      None          6.5          148
# 73                12                   5      None          6.6          819
# 74                 1                None      None          6.6           90
# 1                 18                   3      None          6.2         1499
#
#    date_published           primaryName birthYear deathYear  \
# ...

# %%
# Search for a value in a column

explodedAndMergedDF.loc[explodedAndMergedDF['movie_id'] == 'tt0000002']
# Out:
#        nconst   movie_id                            title review_count_user  \
# 72  nm0721526  tt0000002  A bohóc és kutyái (1892) - IMDb                 0
#
#    review_count_critic metascore rating_value rating_count date_published  \
# 72                None      None          6.5          148     1892-10-28
#
#       primaryName birthYear deathYear primaryProfession  \
# 72  Émile Reynaud      1844      1918          director
#
#                              knownForTitles
# 72  tt2184231,tt0000003,tt2184201,tt0413219

# %%
explodedAndMergedDF['movie_id'].nunique()
# Out:
# 516213

# %%
explodedDF['movie_id'].nunique()
# Out:
# 518285

# %%
explodedAndMergedDF.to_csv(saveMergeFilePath+ '\\explodeNMerged.csv',index=False, encoding="utf8" )
